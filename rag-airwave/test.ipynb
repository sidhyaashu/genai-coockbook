# %%
import os

# %%
from airweave import AirweaveSDK

client = AirweaveSDK(
    api_key="SPq-Ht2Al1di1O0sneLynONYUBjNVw4U_hnfgqLshHQ",
    base_url="http://localhost:8001"
)
client.collections.create_collection(
    name="test",
)
# Out:
# Collection(name='test', readable_id='test-z8bs8j', id='64793118-f363-4f3f-983a-0a75a495954a', created_at=datetime.datetime(2025, 6, 30, 16, 38, 9, 299972), modified_at=datetime.datetime(2025, 6, 30, 16, 38, 9, 299981), organization_id='a2a08d78-93ec-4fc6-b151-04bbfc8c4449', created_by_email='admin@example.com', modified_by_email='admin@example.com', status='NEEDS SOURCE')
